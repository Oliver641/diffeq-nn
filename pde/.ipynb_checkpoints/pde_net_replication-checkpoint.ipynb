# %%
from __future__ import absolute_import, division, print_function

import functools
import sympy
import time
import numpy as np
import scipy as sp
from scipy.fftpack import diff as psdiff

from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.python.keras.utils import conv_utils
from pprint import pprint

from fipy import Variable, FaceVariable, CellVariable, \
                 Grid1D, Grid2D, ExplicitDiffusionTerm, \
                 TransientTerm, DiffusionTerm, ConvectionTerm, FirstOrderAdvectionTerm,\
                 Viewer
from fipy.tools import numerix

# %%
version = tf.__version__
executing_eagerly = tf.executing_eagerly()
gpu_available = tf.test.is_gpu_available()
print('Tensorflow version: {}\n'
      'Executing eagerly: {}\n'
      'GPU available: {}'
      .format(version, 
              executing_eagerly, 
              gpu_available))
# Out:
# Tensorflow version: 2.0.0
# Executing eagerly: True
# GPU available: False

# %% [markdown]
# # Producing Diffusion Data
#
# As in the pde-net, we will be examining solutions to diffusion equations of the form:
#
# \begin{equation}
# \left\{\begin{array}{cc}
# u_t = a(x,y) u_x + b(x,y)u_y + c(x,y)u_{xx} + d(x,y)u_{yy} & \text{for $t,x,y \in [0, 0.2] \times \Omega$}\\
# u\vert_{t=0} = u_0(x,y) & \text{ }
# \end{array}
# \right.
# \end{equation}
#
# Where $\Omega = [0, 2\pi] \times [0, 2\pi]$.  In this paper in particular, they took $c \equiv .2, d\equiv .3$ and
#
# \begin{equation}
# a(x,y) = 0.5(\cos(y) + x(2\pi - x)\sin(x)) + 0.6\\ \\
# b(x,y) = 2(\cos(y) + \sin(x)) + 0.8
# \end{equation}
#
# The initial condition $u_0$ is generated from
#
# \begin{equation}
# u_0(x,y) = \sum_{\vert k\vert, \vert l \vert < N} \lambda_{k,l} \cos(kx+ly) + \gamma_{k,l} \sin(kx+ly)
# \end{equation}
#
# where $\lambda_{k,l}, \gamma_{k,l} \sim N\left(0, \frac{1}{50}\right)$ and $k,l$ are 'chosen randomly'. (What does this mean?)

# %%
def get_equation(a, b, c, d):
    return (TransientTerm()
            == DiffusionTerm([c.flatten(),d.flatten()])
            + FirstOrderAdvectionTerm([a.flatten(),b.flatten()]))

# %%
def generate_initial(x, y, N=9, variance=1/50):
    lambda_kl = variance * np.random.randn(N,N)
    gamma_kl = variance * np.random.randn(N,N)
    return sum(lambda_kl[k,l] * np.cos(k*x + l*y) 
                  + gamma_kl[k,l] * np.sin(k*x+l*y) 
                  for k in range(N) 
                  for l in range(N))

# %%
nx,ny = 50,50
dx,dy = 2*np.pi/nx, 2*np.pi/ny
t=.2
time_step=.01
num_timesteps = int(np.floor(t/time_step))
xx, yy = np.meshgrid(np.linspace(0, 2*np.pi, nx), np.linspace(0, 2*np.pi, ny))
a = .5 * (np.cos(yy) + xx*(2*np.pi - xx) * np.sin(xx)) + .6
b = 2 * (np.cos(yy) + np.sin(xx)) + .8
c = .2 * np.ones((nx,ny))
d = .3 * np.ones((nx,ny))
u_0 = generate_initial(xx,yy)



    
def du_dt(t, u):
    u = u.reshape(nx,ny)
    ux = [psdiff(u_0[i]) for i in range(len(u_0))]
    uxx = [psdiff(u_0[i], order=2) for i in range(len(u_0))]
    uy = [psdiff(u_0[:,i]) for i in range(len(u_0[0]))]
    uyy = [psdiff(u_0[:,i], order=2) for i in range(len(u_0[0]))]

    a = .5 * (np.cos(yy) + xx*(2*np.pi - xx) * np.sin(xx)) + .6
    b = 2 * (np.cos(yy) + np.sin(xx)) + .8
    c = .2 * np.ones((nx,ny))
    d = .3 * np.ones((nx,ny))
    return (a * ux + b * uy + c * uxx + d * uyy).flatten()

# %%
fig, axes = plt.subplots(1, 5)
axes[0].imshow(a, vmin=-4, vmax=4)
axes[0].set_title("a")
axes[1].imshow(b, vmin=-4, vmax=4)
axes[1].set_title("b")
axes[2].imshow(c, vmin=-2, vmax=2)
axes[2].set_title("c")
axes[3].imshow(d, vmin=-2, vmax=2)
axes[3].set_title("d")
axes[4].imshow(u_0, vmin=-2, vmax=2)
axes[4].set_title("u_0")
fig.tight_layout()

# %%
def generate_diffusion(nx, ny, du_dt, t=.2, step_size=.01):
    dx,dy = 2*np.pi/nx, 2*np.pi/ny
    xx, yy = np.meshgrid(np.linspace(0, 2*np.pi, nx), np.linspace(0, 2*np.pi, ny))
    
    u_0 = generate_initial(xx,yy)
    
    solution = sp.integrate.RK45(du_dt, 0, u_0.flatten(), t, max_step=step_size)
    data = np.array([solution.y.reshape(nx,ny)])
    for i in range(int(t/step_size)):
        solution.step()
        data = np.append(data, np.array([solution.y.reshape(nx,ny)]), axis=0)
    return data

# %%
data = generate_diffusion(nx, ny, du_dt, t=t, step_size=time_step)

# %%
def diffusion_data_generator(nx, ny, t, step_size):
    while True:
        x = generate_diffusion(nx, ny, du_dt, t, step_size)
        yield x[0].astype(np.float32), x[1:].astype(np.float32)

# %%
dataset = tf.data.Dataset.from_generator(diffusion_data_generator,
                                         args=[nx, ny, t, time_step], 
                                         output_types=(tf.float32, tf.float32), 
                                         output_shapes=((nx,ny), (num_timesteps, nx, ny)))

# %%
for x,y in dataset.take(1):
    pass

# %%
y.shape
# Out:
# TensorShape([20, 50, 50])

# %%
fig = plt.figure()
ims = [[plt.imshow(datum, animated=True)] for datum in y]
ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgfc843fdd2c93486592ebc9abec01324c">
#   <div class="anim-controls">
#     <input id="_anim_sliderfc843fdd2c93486592ebc9abec01324c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animfc843fdd2c93486592ebc9abec01324c.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animfc843fdd2c93486592ebc9abec01324c.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animfc843fdd2c93486592ebc9abec01324c.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animfc843fdd2c93486592ebc9abec01324c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animfc843fdd2c93486592ebc9abec01324c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animfc843fdd2c93486592ebc9abec01324c.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animfc843fdd2c93486592ebc9abec01324c.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animfc843fdd2c93486592ebc9abec01324c.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animfc843fdd2c93486592ebc9abec01324c.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animfc843fdd2c93486592ebc9abec01324c.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectfc843fdd2c93486592ebc9abec01324c" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_fc843fdd2c93486592ebc9abec01324c"
#              >
#       <label for="_anim_radio1_fc843fdd2c93486592ebc9abec01324c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_fc843fdd2c93486592ebc9abec01324c"
#              checked>
#       <label for="_anim_radio2_fc843fdd2c93486592ebc9abec01324c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_fc843fdd2c93486592ebc9abec01324c"
#              >
#       <label for="_anim_radio3_fc843fdd2c93486592ebc9abec01324c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgfc843fdd2c93486592ebc9abec01324c";
#     var slider_id = "_anim_sliderfc843fdd2c93486592ebc9abec01324c";
#     var loop_select_id = "_anim_loop_selectfc843fdd2c93486592ebc9abec01324c";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8QZhcZAAAgAElEQVR4nO2dWYxc13nn/7VXdfVSvbKb3VzETSIp\
# maREmWOPJxDF0MbYAgVYtsXADzSkDGHDA9jyi/hgwA4QSJQnDqxB8jBEOAjHcCQEerAUyyGiSDbi\
# yKIZJqIsh5FCSs2lm81mb9W1b7fuPBBh8/u+Ezbhybjqtv+/J57qc8797rmXde6t/7eEfN/3QQgh\
# hASMcKsNIIQQQn4duIERQggJJNzACCGEBBJuYIQQQgIJNzBCCCGBhBsYIYSQQMINjBBCSCDhBkYI\
# ISSQcAMjhBASSLiBEUIICSTcwAghhAQSbmCEEEICCTcwQgghgYQbGCGEkEDCDYwQQkgg4QZGCCEk\
# kHADI4QQEki4gRFCCAkk3MAIIYQEEm5ghBBCAgk3MEIIIYGEGxghhJBAwg2MEEJIIOEGRgghJJBw\
# AyOEEBJIuIERQggJJNzACCGEBB

# %% [markdown]
# # Equation Block

# %%
class NonPos(tf.keras.constraints.Constraint):
    """Constrains the weights incident to each hidden unit to Negative.
    """

    def __init__(self):
        pass

    def __call__(self, w):
        w = w * K.cast(K.less_equal(w, 0.), K.floatx())
        return w

# %%
def wrap_padding(x, padding=1):
    for i, p in enumerate(padding):
        if p[0] > 0 and p[1] > 0:
            x = tf.concat([tf.gather(x, list(range(x.shape[i] - p[0], x.shape[i])), axis=i), 
                          x, 
                          tf.gather(x, list(range(p[1])), axis=i)], axis=i)
        elif p[0] > 0:
            x = tf.concat([tf.gather(x, list(range(x.shape[i] - p[0], x.shape[i])), axis=i), 
                          x], axis=i)
        elif p[1] > 0:
            x = tf.concat([x, 
                          tf.gather(x, list(range(p[1])), axis=i)], axis=i)
        else:
            pass
        
    return x

WrapPadding = lambda padding: tf.keras.layers.Lambda(lambda x: wrap_padding(x, padding))

# %%
class DeltaT(tf.keras.layers.Layer):
    
    def __init__(self, 
                 nx, 
                 ny,
                 filter_size,
                 order=2,
                 diff_mode='constant',
                 strides=(1,1),
                 padding='valid',
                 data_format='channels_last',
                 dilation_rate=(1,1),
                 functional_initializer='glorot_uniform',
                 functional_regularizer=None,
                 activation=None,
                 activity_regularizer=None,
                 trainable=True,
                 **kwargs):
        
        super(DeltaT, self).__init__(**kwargs)
        self.nx = nx
        self.ny = ny
        self.filter_size = filter_size
        self.state_size = [nx*ny*num_filters]
        self.order = order
        self.diff_mode = diff_mode
        
        self.strides = strides
        self.padding = padding
        self.data_format = data_format
        self.dilation_rate = dilation_rate
        
        self.functional_initializer = functional_initializer
        self.functional_regularizer = functional_regularizer
        self.activation = activation
        self.activity_regularizer = activity_regularizer
        self.trainable = trainable
        self.equation_block = {}
            
        self.q = {
            (0,0): np.array([[1,1,1], [1,1,1], [1,1,1]])/9,
            (1,0): np.array([[1,2,1], [0,0,0], [-1,-2,-1]])/8,
            (0,1): (np.array([[1,2,1], [0,0,0], [-1,-2,-1]])/8).T,
            (2,0): np.array([[0,0,0], [1,-2,1], [0,0,0]]),
            (0,2): (np.array([[0,0,0], [1,-2,1], [0,0,0]])).T,
            (1,1): np.array([[1, 0, -1], [0,0,0], [-1,0,1]])/2
        }
        
        
    def build(self, input_shape):
        if self.data_format == 'channels_first':
            channel_axis = 1
        else:
            channel_axis = -1
        if input_shape[channel_axis] is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        
        input_dim = input_shape[channel_axis]
        self.kernel_size = (self.order+1, self.order+1, 1, 1)
            
        if self.diff_mode not in ['constant']:
            raise Exception(self.diff_mode)
        if self.diff_mode == 'constant':
            assert self.order == 2
            for pair, wavelet in self.q.items():
                self.equation_block[pair] = {
                    'D': self.add_weight(shape=self.kernel_size,
                                         initializer=tf.keras.initializers.Constant(wavelet),
                                         name='D_{}{}'.format(*pair),
                                         trainable=False),
                    'c': self.add_weight(shape=(1, nx, ny, self.num_filters),
                                         initializer=self.functional_initializer,
                                         name='c_{}{}'.format(*pair),
                                         regularizer=self.functional_regularizer,
                                         trainable=self.trainable)
                }
        
        self.wrap_padding = WrapPadding(((0,0), (1,1), (1,1), (0,0)))
        self.reshape = tf.keras.layers.Reshape((nx, ny, num_filters))
        self.flatten = tf.keras.layers.Flatten()
        
        self.built = True
        
    def _call_block(self, padded_inputs, pair):
        outputs = K.conv2d(
            padded_inputs,
            self.equation_block[pair]['D'],
            strides=self.strides[0],
            data_format=self.data_format,
            dilation_rate=self.dilation_rate[0]
        )
        outputs = self.equation_block[pair]['c'] * outputs
        return outputs
        
    def call(self, inputs, state):
        outputs = self.reshape(state[0])
        outputs = self.wrap_padding(outputs)
        outputs = K.sum([self._call_block(outputs, pair) for pair in self.equation_block.keys()], axis=0)
        
        if self.activation is not None:
            return self.activation(outputs)
        
        return outputs, [self.flatten(outputs)]
    
    def visualize(self):
        fig = plt.figure()

        for i in range(self.equation_order+1):
            for j in range(self.equation_order+1):
                if(i+j<=self.equation_order):
                    ax = plt.subplot2grid((5,5), (2*i,2*j))
                    ax.axis('off')
                    ax.imshow(self.equation_blocks[(i,j)].c[:,:,:,index]
                                  .numpy().reshape(4,4), 
                              norm=plt.Normalize(-1.,1.), cmap='viridis')
                    ax.title.set_text("c_{}{}".format(i,j))
        fig.show()

# %%
d_x = np.array([-1,1]).reshape(2,1,1,1)
d_y = np.array([-1,1]).reshape(1,2,1,1)

def gradient_l2(param, filter_size):
    def _gradient_l2(weight_matrix):
        W = K.transpose(K.reshape(weight_matrix, (1,4,4,filter_size)))
        W_x = K.conv2d(W,d_x)
        W_y = K.conv2d(W,d_y)
        return param * K.sum([K.sum(K.square(W)),
                              K.sum(K.square(W_x)),
                              K.sum(K.square(W_y))])
        
    return _gradient_l2

# %%
batch_size = 32
num_filters = 20
delta_t = DeltaT(nx,ny, num_filters)
partial = tf.keras.layers.RNN(delta_t, return_sequences=True)

# %%
t0 = time.time()
for x, y in dataset.batch(batch_size).take(1):
    pass
reshape = tf.keras.layers.Reshape((nx*ny,))
repeat = tf.keras.layers.RepeatVector(num_filters)
permute = tf.keras.layers.Permute([2,1])
reshape2 = tf.keras.layers.Reshape((nx,ny,num_filters))
flatten = tf.keras.layers.Flatten()
o_e = flatten(permute(repeat(reshape(x))))
boop = partial(tf.zeros((batch_size,20,nx,ny,1)), [o_e])
print(time.time() - t0)
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-44-da3d3043252f> in <module>
#       8 flatten = tf.keras.layers.Flatten()
#       9 o_e = flatten(permute(repeat(reshape(x))))
# ---> 10 boop = partial(tf.zeros((batch_size,20,nx,ny,1)), [o_e])
#      11 print(time.time() - t0)
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     671       if constants is not None:
#     672         kwargs['constants'] = constants
# --> 673       return super(RNN, self).__call__(inputs, **kwargs)
#     674
#     675   def call(self,
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state, constants)
#     754         input_length=input_length,
#     755         time_major=self.time_major,
# --> 756         zero_output_for_mask=self.zero_output_for_mask)
#     757     if self.stateful:
#     758       updates = []
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask)
#    4033     # the value is discarded.
#    4034     output_time_zero, _ = step_function(
# -> 4035         input_time_zero, tuple(initial_states) + tuple(constants))
#    4036     output_ta = tuple(
#    4037         tensor_array_ops.TensorArray(
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/layers/recurrent.py in step(inputs, states)
#     730       def step(inputs, states):
#     731         states = states[0] if len(states) == 1 and is_tf_rnn_cell else states
# --> 732         output, new_states = self.cell.call(inputs, states, **kwargs)
#     733         if not nest.is_sequence(new_states):
#     734           new_states = [new_states]
#
# <ipython-input-17-e13531cb7fbe> in call(self, inputs, state)
#     107         outputs = self.reshape(state[0])
#     108         outputs = self.wrap_padding(outputs)
# --> 109         outputs = K.sum([self._call_block(outputs, pair) for pair in self.equation_block.keys()], axis=0)
#     110
#     111         if self.activation is not None:
#
# <ipython-input-17-e13531cb7fbe> in <listcomp>(.0)
#     107         outputs = self.reshape(state[0])
#     108         outputs = self.wrap_padding(outputs)
# --> 109         outputs = K.sum([self._call_block(outputs, pair) for pair in self.equation_block.keys()], axis=0)
#     110
#     111         if self.activation is not None:
#
# <ipython-input-17-e13531cb7fbe> in _call_block(self, padded_inputs, pair)
#      99             strides=self.strides[0],
#     100             data_format=self.data_format,
# --> 101             dilation_rate=self.dilation_rate[0]
#     102         )
#     103         outputs = self.equation_block[pair]['c'] * outputs
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in conv2d(x, kernel, strides, padding, data_format, dilation_rate)
#    4860       strides=strides,
#    4861       padding=padding,
# -> 4862       data_format=tf_data_format)
#    4863   if data_format == 'channels_first' and tf_data_format == 'NHWC':
#    4864     x = array_ops.transpose(x, (0, 3, 1, 2))  # NHWC -> NCHW
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in convolution(input, filter, padding, strides, dilation_rate, name, data_format, filters, dilations)
#     896       data_format=data_format,
#     897       dilations=dilation_rate,
# --> 898       name=name)
#     899
#     900
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution)
#    1007           data_format=data_format,
#    1008           dilations=dilations,
# -> 1009           name=name)
#    1010     else:
#    1011       if channel_index == 1:
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1037       else:
#    1038         message = e.message
# -> 1039       _six.raise_from(_core._status_to_exception(e.code, message), None)
#    1040   # Add nodes to the TensorFlow graph.
#    1041   if not isinstance(strides, (list, tuple)):
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# UnimplementedError: The Conv2D op currently does not support grouped convolutions on the CPU. A grouped convolution was attempted to be run because the input depth of 20 does not match the filter input depth of 1 [Op:Conv2D] name: rnn_2/convolution/

# %%
o_e = reshape2(permute(repeat(reshape(x))))

# %%
o_e.shape
# Out:
# TensorShape([32, 50, 50, 20])

# %%
outputs = K.conv2d(
    o_e,
    delta_t.equation_block[(0,2)]['D'],
    strides=delta_t.strides[0],
    data_format=delta_t.data_format,
    dilation_rate=delta_t.dilation_rate[0]
)
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-50-10ecdbb11aaa> in <module>
#       4     strides=delta_t.strides[0],
#       5     data_format=delta_t.data_format,
# ----> 6     dilation_rate=delta_t.dilation_rate[0]
#       7 )
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in conv2d(x, kernel, strides, padding, data_format, dilation_rate)
#    4860       strides=strides,
#    4861       padding=padding,
# -> 4862       data_format=tf_data_format)
#    4863   if data_format == 'channels_first' and tf_data_format == 'NHWC':
#    4864     x = array_ops.transpose(x, (0, 3, 1, 2))  # NHWC -> NCHW
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in convolution(input, filter, padding, strides, dilation_rate, name, data_format, filters, dilations)
#     896       data_format=data_format,
#     897       dilations=dilation_rate,
# --> 898       name=name)
#     899
#     900
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution)
#    1007           data_format=data_format,
#    1008           dilations=dilations,
# -> 1009           name=name)
#    1010     else:
#    1011       if channel_index == 1:
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1037       else:
#    1038         message = e.message
# -> 1039       _six.raise_from(_core._status_to_exception(e.code, message), None)
#    1040   # Add nodes to the TensorFlow graph.
#    1041   if not isinstance(strides, (list, tuple)):
#
# /opt/miniconda3/envs/oliver_tf2/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# UnimplementedError: The Conv2D op currently does not support grouped convolutions on the CPU. A grouped convolution was attempted to be run because the input depth of 20 does not match the filter input depth of 1 [Op:Conv2D] name: convolution/

# %% [markdown]
# # PDE Model

# %%
class PDENet(tf.keras.Model):
    
    def __init__(self, nx, ny, num_timesteps, filter_size):
        super(PDENet, self).__init__(name='pde_net')
        
        self.reshape = tf.keras.layers.Reshape((nx, ny, 1))
        self.repeat = tf.keras.layers.RepeatVector(num_filters)
        self.flatten = tf.keras.layers.Flatten()
        self.delta_t = DeltaT(nx, ny,filter_size)
        self.equation_layer = tf.keras.layers.RNN(self.delta_t, return_sequences=True)
        
    def call(self, input_tensor, training=False):
        x = self.reshape(input_tensor)
        x = self.flatten(x)
        x = self.equation_layer(tf.zeros((batch_size,t/time_step, nx, ny, 1)), x)
        return x

# %%
filter_size=1
epochs=10

# %%
model = PDENet(nx,ny,num_timesteps, filter_size)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.mean_squared_error,
              metrics=[tf.keras.metrics.mean_squared_error])

# %%
dataset = tf.data.Dataset.from_generator(diffusion_data_generator,
                                         args=[nx, ny, t, time_step], 
                                         output_types=(tf.float32, tf.float32), 
                                         output_shapes=((nx,ny), (num_timesteps, nx, ny)))

# %%
h=model.fit(dataset.batch(32), epochs=epochs, steps_per_epoch=10)
# Out:
# (None, 2500)
# Train for 10 steps
# Epoch 1/10
# (None, 2500)
# (None, 2500)
# 10/10 [==============================] - 48s 5s/step - loss: 0.2434 - mean_squared_error: 0.2434
# Epoch 2/10
# 10/10 [==============================] - 46s 5s/step - loss: 0.2438 - mean_squared_error: 0.2438
# Epoch 3/10
# 10/10 [==============================] - 47s 5s/step - loss: 0.2435 - mean_squared_error: 0.2435
# Epoch 4/10
# 10/10 [==============================] - 46s 5s/step - loss: 0.2434 - mean_squared_error: 0.2434
# Epoch 5/10
# 10/10 [==============================] - 46s 5s/step - loss: 0.2434 - mean_squared_error: 0.2434
# Epoch 6/10
# 10/10 [==============================] - 46s 5s/step - loss: 0.2435 - mean_squared_error: 0.2435
# Epoch 7/10
# 10/10 [==============================] - 46s 5s/step - loss: 0.2435 - mean_squared_error: 0.2435
# Epoch 8/10
# 10/10 [==============================] - 46s 5s/step - loss: 0.2434 - mean_squared_error: 0.2434
# Epoch 9/10
# 10/10 [==============================] - 46s 5s/step - loss: 0.2438 - mean_squared_error: 0.2438
# Epoch 10/10
# 10/10 [==============================] - 46s 5s/step - loss: 0.2433 - mean_squared_error: 0.2433
